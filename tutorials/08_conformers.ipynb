# %% [markdown]
# # Introduction to Neural Force Field

# %% [markdown]
# This Jupyter Notebook contains an introduction to the `nff` package. Here, we will load the modules and functions from `nff` to import a dataset, create dataloaders, create a model, train it and check the test stats. We will do most of it manually to illustrate the usage of the API. However, scripts such as the one provided in the `scripts/` folder already automate most of this process.

# %% [markdown]
# After the `nff` package has been installed, we start by importing all dependencies for this tutorial.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(0, "..")
# sys.path.insert(0, "/home/saxelrod/Repo/projects/covid_nff/NeuralForceField")
# sys.path.remove('/home/saxelrod/Repo/projects/ax_autopology/NeuralForceField')

import os
import shutil
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.optim import Adam
from torch.utils.data import DataLoader

from nff.data import Dataset, split_train_validation_test, collate_dicts, to_tensor
from nff.train import Trainer, get_trainer, get_model, load_model, loss, hooks, metrics, evaluate

# %% [markdown]
# It might also be useful setting the GPU you want to use:

# %%
# DEVICE = 1
# OUTDIR = './sandbox'
# model = load_model(OUTDIR)

# %%
DEVICE = 3
OUTDIR = './sandbox'

if os.path.exists(OUTDIR):
    newpath = os.path.join(os.path.dirname(OUTDIR), 'backup')
    if os.path.exists(newpath):
        shutil.rmtree(newpath)
        
    shutil.move(OUTDIR, newpath)

# %% [markdown]
# ## Loading the relevant data

# %% [markdown]
# As we usually work with the database, we can pack their information in a class `Dataset`, which is a subclass of `torch.utils.data.Dataset`. It basically wraps information on the atomic numbers, energies, forces and SMILES strings for each one of the geometries. In this example, we already have a pre-compiled `Dataset` to be used. We start by loading this file and creating three slices of the original dataset

# %%
# dataset = Dataset.from_file('./data/covid.pth.tar')
dataset = Dataset.from_file('./data/covid_mmff94.pth.tar')
# dataset = Dataset.from_file('./data/covid_mmff94_1_geom.pth.tar')

# %%
import pdb

def separate_datasets(dataset, split_ratio):

    bind_indices = torch.LongTensor([i  for i, bind in enumerate(dataset.props['bind']) if bind])
    remaining_indices = [i for i in range(len(dataset)) if i not in bind_indices]

    fail_dataset = dataset.copy()
    for key, val in fail_dataset.props.items():
        fail_dataset.props[key] = [val[i] for i in remaining_indices]
    return dataset, fail_dataset, bind_indices

def get_split_bind_indices(bind_indices, split_ratio):
    num_bind = len(bind_indices)
    bind_per_split = (split_ratio * num_bind).astype('int')
    while True:
        for i in range(3):
            if sum(bind_per_split) == num_bind:
                break
            bind_per_split[i] += 1
        if sum(bind_per_split) == num_bind:
                break

    bind_per_split = bind_per_split.tolist()
    split_bind_indices = torch.split(bind_indices, bind_per_split)
    return split_bind_indices

def make_bind_datasets(split_bind_indices, dataset):
    
    datasets = []
    for indices in split_bind_indices:
        new_set = dataset.copy()
        for key, val in dataset.props.items():
            new_set.props[key] = to_tensor([val[i] for i in indices])
        datasets.append(new_set)
    return tuple(datasets)
    

def split_data(dataset, split_ratio):
    dataset, fail_dataset, bind_indices = separate_datasets(dataset, split_ratio)
    split_bind_indices =  get_split_bind_indices(bind_indices, split_ratio)
    bind_datasets = make_bind_datasets(split_bind_indices, dataset)
    
    train, val, test = split_train_validation_test(fail_dataset, val_size=0.2, test_size=0.2)
    split_sets = [train, val, test]
    
    for i in range(3):
        split_set = split_sets[i]
        bind_set = bind_datasets[i]
        
        for key, value in bind_set.props.items():
            if type(value) is list:
                split_set.props[key] += value
            else:
                split_set.props[key] = torch.cat((split_set.props[key], value))
    
    return train, val, test

# %%
split_ratio = np.array([0.6, 0.2, 0.2])
train, val, test = split_data(dataset, split_ratio)

# %% [markdown]
# The `nff` code interfaces with the `graphbuilder` module through a git submodule in the repository. `graphbuilder` provides methods to create batches of graphs. In `nff`, we interface that through a custom dataloader called `
# GraphLoader`. Here, we create one loader for each one of the slices.

# %%
train_loader = DataLoader(train, batch_size=5, collate_fn=collate_dicts)
val_loader = DataLoader(val, batch_size=5, collate_fn=collate_dicts)
test_loader = DataLoader(test, batch_size=5, collate_fn=collate_dicts)

# %%
print(torch.sum(train.props['bind']))
print(torch.sum(val.props['bind']))
print(torch.sum(test.props['bind']))
# Out:
# tensor(15)
# tensor(5)
# tensor(5)

# %% [markdown]
# ## Creating a model

# %% [markdown]
# `nff` is based on SchNet. It parameterizes interatomic interactions in molecules and materials through a series of convolution layers with continuous filters. Here, we are going to create a simple model using the hyperparameters given on `params`:

# %%
n_atom_basis = 256
mol_basis = 256

mol_fp_layers = [{'name': 'linear', 'param' : { 'in_features': n_atom_basis,
                                                              'out_features': int((n_atom_basis + mol_basis)/2)}},
                               {'name': 'shifted_softplus', 'param': {}},
                               {'name': 'linear', 'param' : { 'in_features': int((n_atom_basis + mol_basis)/2),
                                                              'out_features': mol_basis}}]

readoutdict = {
                    "bind": [{'name': 'linear', 'param' : { 'in_features': mol_basis,
                                                              'out_features': int(mol_basis / 2)}},
                               {'name': 'shifted_softplus', 'param': {}},
                               {'name': 'linear', 'param' : { 'in_features': int(mol_basis / 2),
                                                              'out_features': 1}},
                               {'name': 'sigmoid', 'param': {}}],
                }

params = {
    'n_atom_basis': n_atom_basis,
    'n_filters': 256,
    'n_gaussians': 32,
    'n_convolutions': 4,
    'cutoff': 5.0,
    'trainable_gauss': True,
    'dropout_rate': 0.2,
    'mol_fp_layers': mol_fp_layers,
    'readoutdict': readoutdict
}


model = get_model(params=params, model_type='WeightedConformers')

# %% [markdown]
# ## Creating a trainer

# %% [markdown]
# To train our model with the data provided, we have to create a loss function. The easiest way to do that is through the `build_mse_loss` builder. Its argument `rho` is a parameter that will multiply the mean square error (MSE) of the force components before summing it with the MSE of the energy.

# %%
loss_fn = loss.build_cross_entropy_loss(loss_coef={'bind': 1.0})

# %% [markdown]
# We should also select an optimizer for our recently created model:

# %%
trainable_params = filter(lambda p: p.requires_grad, model.parameters())
optimizer = Adam(trainable_params, lr=3e-4)

# %% [markdown]
# ### Metrics and hooks

# %% [markdown]
# Metrics and hooks allow the customization of the training process. Instead of tweaking directly the code or having to resort to countless flags, we can create submodules (or add-ons) to monitor the progress of the training or customize it.

# %% [markdown]
# If we want to monitor the progress of our training, say by looking at the mean absolute error (MAE) of energies and forces, we can simply create metrics to observe them:

# %%
train_metrics = [
    metrics.TruePositives('bind'),
    metrics.TrueNegatives('bind'),
    metrics.FalsePositives('bind'),
    metrics.FalseNegatives('bind'),

]

# %% [markdown]
# Furthermore, if we want to customize how our training procedure is done, we can use hooks which can interrupt or change the train automatically.
#
# In our case, we are adding hooks to:
# * Stop the training procedure after 100 epochs;
# * Log the training on a machine-readable CSV file under the directory `./sandbox`;
# * Print the progress on the screen with custom formatting; and
# * Setup a scheduler for the learning rate.

# %%
train_hooks = [
    hooks.MaxEpochHook(100),
    hooks.CSVHook(
        OUTDIR,
        metrics=train_metrics,
    ),
    hooks.PrintingHook(
        OUTDIR,
        metrics=train_metrics,
        separator = ' | ',
        time_strf='%M:%S'
    ),
    hooks.ReduceLROnPlateauHook(
        optimizer=optimizer,
        patience=30,
        factor=0.5,
        min_lr=1e-7,
        window_length=1,
        stop_after_min=True
    )
]

# %% [markdown]
# ### Trainer wrapper

# %% [markdown]
# A `Trainer` in the `nff` package is a wrapper to train a model. It automatically creates checkpoints, as well as trains and validates a given model. It also allow further training by loading checkpoints from existing paths, making the training procedure more flexible. Its functionalities can be extended by the hooks we created above. To create a trainer, we have to execute the following command:

# %%
T = Trainer(
    model_path=OUTDIR,
    model=model,
    loss_fn=loss_fn,
    optimizer=optimizer,
    train_loader=train_loader,
    validation_loader=val_loader,
    checkpoint_interval=1,
    hooks=train_hooks
)

# %% [markdown]
# Now we can finally train the model using the method `train` from the `Trainer`:

# %%
T.train(device=DEVICE, n_epochs=100)
# Out:
#  Time | Epoch | Learning rate | Train loss | Validation loss | TruePositive_bind | TruePositive_bind | FalsePositive_bind | FalseNegative_bind | GPU Memory (MB)
# {'bind': tensor([[0.2880],
#         [0.4413],
#         [0.1353],
#         [0.2011],
#         [0.3029]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[3.3886e-03],
#         [1.0787e-02],
#         [1.8957e-12],
#         [4.5077e-02],
#         [8.0078e-15]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[6.4961e-10],
#         [1.9612e-18],
#         [6.6281e-12],
#         [5.4408e-14],
#         [6.3246e-18]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[8.1148e-15],
#         [2.0362e-14],
#         [2.6469e-14],
#         [8.5418e-10],
#         [3.3492e-22]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[4.1015e-17],
#         [0.0000e+00],
#         [9.7186e-33],
#         [1.7656e-01],
#         [4.7977e-08]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[1.0586e-16],
#         [5.9509e-16],
#         [4.2171e-21],
#         [3.0186e-25],
#         [7.9610e-31]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[2.5186e-31],
#         [6.5828e-29],
#         [5.5225e-17],
#         [5.9128e-18],
#         [2.7450e-21]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[6.3046e-07],
#         [2.5633e-36],
#         [9.5860e-27],
#         [4.2353e-32],
#         [3.7942e-13]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[5.0841e-08],
#         [1.7629e-23],
#         [0.0000e+00],
#         [5.2795e-16],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[4.7121e-17],
#         [1.3157e-31],
#         [1.1309e-29],
#         [9.4737e-36],
#         [1.4125e-12]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[4.5692e-20],
#         [0.0000e+00],
#         [3.0263e-24],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [1.0656e-13],
#         [1.4587e-35],
#         [3.3532e-37],
#         [2.8534e-11]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[5.0472e-10],
#         [2.0048e-11],
#         [0.0000e+00],
#         [9.8667e-37],
#         [8.3532e-29]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[3.3676e-29],
#         [2.4493e-37],
#         [0.0000e+00],
#         [9.4651e-33],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [9.6253e-27],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[8.2240e-28],
#         [2.5232e-28],
#         [7.3359e-07],
#         [2.0152e-10],
#         [2.7871e-33]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [1.5343e-24],
#         [1.0570e-19],
#         [0.0000e+00],
#         [4.3255e-03]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [5.3950e-24]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.3401e-31],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [7.1289e-17],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [3.9363e-30],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[5.7084e-36],
#         [0.0000e+00],
#         [0.0000e+00],
#         [2.3547e-35],
#         [3.5615e-21]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [1.2740e-38],
#         [1.0989e-29],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[4.3986e-21],
#         [2.2349e-37],
#         [0.0000e+00],
#         [5.3530e-31],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [7.3871e-35],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[2.0459e-26],
#         [2.2785e-15],
#         [1.4348e-06],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[2.6135e-28],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[1.4991e-20],
#         [0.0000e+00],
#         [2.0097e-35],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.1718e-33]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [4.5819e-29]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[2.0809e-17],
#         [1.9161e-28],
#         [0.0000e+00],
#         [0.0000e+00],
#         [4.8494e-37]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [7.4705e-33]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [1.1906e-24],
#         [1.0271e-29],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [4.2232e-22]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[2.7432e-10],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [2.0459e-18]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [3.3295e-39]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [6.9372e-29]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [2.0420e-25]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.4220e-20],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[1.6472e-32],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.5384e-36],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [6.4492e-34],
#         [0.0000e+00],
#         [2.3475e-30],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [8.5805e-20]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[3.0138e-15],
#         [0.0000e+00],
#         [0.0000e+00],
#         [6.1364e-30],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[5.6104e-38],
#         [0.0000e+00],
#         [0.0000e+00],
#         [9.0621e-38],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [1.2730e-26],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [3.4405e-30],
#         [2.2269e-22],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[3.8885e-24],
#         [0.0000e+00],
#         [1.0252e-20],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [3.9424e-33]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [1.7162e-14],
#         [0.0000e+00],
#         [8.4110e-30]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [4.0840e-19],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[8.3843e-20],
#         [5.0919e-15],
#         [7.3036e-24],
#         [0.0000e+00],
#         [3.5771e-37]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[1.4848e-19],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [5.9882e-37]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[1.3046e-31],
#         [0.0000e+00],
#         [0.0000e+00],
#         [2.9477e-13],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [2.1648e-30],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[1.9600e-30],
#         [8.2644e-34],
#         [0.0000e+00],
#         [5.9010e-31],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [3.9938e-30]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [3.4307e-32],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [6.9894e-36],
#         [0.0000e+00],
#         [9.6276e-24]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [5.4289e-19],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000],
#         [0.0000],
#         [0.0000],
#         [0.0028],
#         [0.0000]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [3.9232e-33],
#         [0.0000e+00],
#         [8.9479e-26]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[8.2695e-29],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [6.4729e-22],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [8.0914e-37],
#         [5.9429e-26]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.9079e-36]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0014],
#         [0.0000],
#         [0.0000],
#         [0.0000],
#         [0.0000]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [2.5446e-08],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.8394e-20]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [4.5488e-32],
#         [0.0000e+00],
#         [2.8232e-21],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[4.7755e-22],
#         [3.9327e-39],
#         [2.1205e-30],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [9.7058e-28]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [2.3304e-24]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[7.3673e-34],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [3.1609e-34]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[9.2401e-37],
#         [1.4285e-14],
#         [0.0000e+00],
#         [0.0000e+00],
#         [6.4970e-31]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [6.5561e-19]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[3.1266e-30],
#         [0.0000e+00],
#         [2.1563e-31],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [5.9534e-19],
#         [5.4055e-12]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [3.7731e-18],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[1.9357e-24],
#         [3.6348e-33],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [1.1747e-36],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [4.3982e-23]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [3.0133e-28],
#         [2.9897e-36],
#         [8.8137e-20],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[9.1273e-10],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.0134e-18]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [1.0663e-09],
#         [7.0950e-19],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[2.2503e-34],
#         [1.2389e-36],
#         [3.6604e-31],
#         [0.0000e+00],
#         [1.1153e-37]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[2.9098e-30],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [4.0676e-28]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [3.9797e-10],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [1.0276e-16],
#         [1.3901e-23],
#         [7.6500e-20],
#         [3.4436e-39]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000],
#         [0.0000],
#         [0.0724],
#         [0.0000],
#         [0.0000]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.0492e-21]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[7.2130e-24],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[2.4119e-08],
#         [0.0000e+00],
#         [0.0000e+00],
#         [2.0948e-30],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [3.0156e-14],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[2.3629e-31],
#         [0.0000e+00],
#         [4.8771e-14],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [4.3343e-25],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[1.1429e-28],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [1.2053e-19],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[1.5468e-28],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.7436e-29],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[7.6935e-09],
#         [0.0000e+00],
#         [4.9851e-12],
#         [1.2235e-30],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [6.6064e-21],
#         [2.9281e-38],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[1.3114e-34],
#         [8.0951e-22],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [1.8943e-22],
#         [0.0000e+00],
#         [3.3634e-25],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.0813e-21],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.8744e-16]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[7.0662e-29],
#         [2.0508e-13],
#         [0.0000e+00],
#         [0.0000e+00],
#         [4.8049e-11]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[2.3021e-02],
#         [2.2556e-27],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.7530e-32],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [3.9603e-23],
#         [3.6516e-37],
#         [1.5465e-27]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [2.1626e-37],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [3.5788e-25],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [5.6890e-39],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.6067e-21],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[1.4667e-19],
#         [0.0000e+00],
#         [5.3057e-13],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [5.9252e-39],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [4.2052e-29]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [3.2288e-38],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[1.1129e-35],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [5.5413e-09],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [3.5214e-15],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [1.7769e-37],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [1.6964e-23],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [8.7723e-15],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [4.6330e-21],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[1.6896e-10],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [3.1244e-11],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[2.3008e-16],
#         [0.0000e+00],
#         [9.2853e-39],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[1.7927e-22],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [5.7411e-15],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[1.2381e-31],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.4352e-31],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[2.1092e-37],
#         [0.0000e+00],
#         [0.0000e+00],
#         [7.0158e-25],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [1.1358e-14],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [4.2683e-32]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[2.7570e-10],
#         [0.0000e+00],
#         [1.3327e-05],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [2.1131e-28]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [3.5589e-06],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[8.2902e-27],
#         [5.6152e-12],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.1697e-33]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.5488e-23],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [1.0402e-20],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [2.2179e-36],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.1797e-28]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [1.1133e-25],
#         [0.0000e+00],
#         [7.6551e-11]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[5.8875e-22],
#         [0.0000e+00],
#         [0.0000e+00],
#         [4.1453e-36],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[1.4348e-21],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [3.4057e-27],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.6614e-06],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[3.8264e-23],
#         [1.2096e-36],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [8.1031e-12],
#         [8.6574e-10],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [7.2929e-31],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.3423e-21]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [1.0559e-32],
#         [3.3577e-16],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [6.8219e-30],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [3.0614e-17],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[3.2286e-24],
#         [2.0373e-08],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [2.1328e-30],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [7.9122e-17],
#         [1.7421e-13],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000],
#         [0.0000],
#         [0.0000],
#         [0.0000],
#         [0.3715]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [3.6297e-37],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [4.9081e-18],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [1.2479e-36],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [1.9928e-12],
#         [0.0000e+00],
#         [2.2929e-21]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [1.0786e-23],
#         [0.0000e+00],
#         [1.1225e-34]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[7.6294e-30],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [5.9394e-05],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [5.8733e-14],
#         [1.4477e-17],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.0563e-29]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [7.1419e-09],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [2.9493e-31]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [3.7197e-20],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[9.1450e-28],
#         [0.0000e+00],
#         [1.5204e-19],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [3.5052e-37],
#         [7.0373e-12],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [5.0146e-11]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [2.2171e-38],
#         [3.8904e-14],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [1.1986e-38],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [5.3595e-35],
#         [1.2512e-38],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.5799e-32]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [1.0553e-27],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [7.3436e-18],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [8.4275e-14],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [3.9755e-33]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [1.1903e-22],
#         [0.0000e+00],
#         [1.2252e-19]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [6.2453e-08],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [8.9222e-22],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [1.2827e-24],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [4.3788e-22],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [2.7980e-23],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[3.0903e-25],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [7.8511e-20]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [8.2625e-39]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[1.4284e-13],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.5258e-25]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.0352e-27],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [6.2655e-27],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [8.6185e-31],
#         [0.0000e+00],
#         [1.0833e-30],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[9.7258e-18],
#         [6.2590e-20],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [4.3007e-07],
#         [1.1311e-29],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [5.1862e-24],
#         [0.0000e+00],
#         [0.0000e+00],
#         [2.6352e-18]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [2.2334e-34],
# ...
#         [2.0120e-38]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [1.0074e-18],
#         [0.0000e+00],
#         [0.0000e+00],
#         [8.4618e-15]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [2.2260e-22]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[1.4834e-35],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [8.8537e-20],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [5.7675e-12],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.0127e-05],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [6.2758e-19]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [2.0027e-29]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [3.5361e-36],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [3.3950e-30],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [2.7712e-24],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[2.2052e-20],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[5.1363e-19],
#         [2.1823e-34],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [1.6192e-08],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[8.5954e-17],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [3.9121e-36],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [4.1684e-18],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[4.5194e-22],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [5.6510e-08],
#         [8.4478e-27],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [2.5478e-24],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [9.9690e-28],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [3.0800e-12]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [2.2516e-21],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [8.6765e-13],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [2.8535e-37],
#         [0.0000e+00],
#         [5.0126e-17]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [8.4843e-35],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[6.0325e-27],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [2.2241e-23],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [3.3660e-21],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [3.8195e-19],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [3.5546e-29],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [3.4438e-21],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[4.6234e-38],
#         [2.7444e-35],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [9.7594e-26],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [4.6663e-26],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [3.8670e-12],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [8.1097e-28],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [4.9468e-27],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [3.9488e-35],
#         [0.0000e+00],
#         [3.4440e-21]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [9.4448e-31]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [2.0730e-35],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.4112e-19],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[6.6731e-31],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [7.0747e-22],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [1.9218e-21],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [4.8374e-28],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [2.4660e-28],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [3.8641e-24]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00],
#         [1.4756e-36],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [4.8594e-27],
#         [0.0000e+00],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.0000e+00],
#         [0.0000e+00],
#         [5.4961e-35],
#         [0.0000e+00],
#         [0.0000e+00]], device='cuda:3', grad_fn=<SigmoidBackward>)}
# {'bind': tensor([[0.],
#         [0.],
#         [0.],
#         [0.],
#         [0.]], device='cuda:3', grad_fn=<SigmoidBackward>)}

# %% [markdown]
# ## Evaluating the model on the test set

# %% [markdown]
# Now we have a brand new model trained and validated. We can use the best model from this training to evaluate its performance on the test set. `results` contains the predictions of properties for the whole test dataset. `targets` contains the ground truth for such data. `test_loss` is the loss, calculated with the same function used during the training part

# %%
results, targets, val_loss = evaluate(T.get_best_model(), test_loader, loss_fn, device=DEVICE)

# %%
to_tensor(results['energy'], stack=True).shape

# %% [markdown]
# Finally, we can plot our results to observe how well is our model performing:

# %%
units = {
    'energy_grad': r'kcal/mol/$\AA$',
    'energy': 'kcal/mol'
}

fig, ax_fig = plt.subplots(1, 2, figsize=(12, 6))

for ax, key in zip(ax_fig, units.keys()):
    pred = torch.stack(results[key], dim=0).view(-1).detach().cpu().numpy()
    targ = torch.stack(targets[key], dim=0).view(-1).detach().cpu().numpy()
    
    ax.scatter(pred, targ, color='#ff7f0e', alpha=0.3)
    
    lim_min = min(np.min(pred), np.min(targ)) * 1.1
    lim_max = max(np.max(pred), np.max(targ)) * 1.1
    
    ax.set_xlim(lim_min, lim_max)
    ax.set_ylim(lim_min, lim_max)
    ax.set_aspect('equal')
    
    ax.plot((lim_min, lim_max),
            (lim_min, lim_max),
            color='#000000',
            zorder=-1,
            linewidth=0.5)
    
    ax.set_title(key.upper(), fontsize=14)
    ax.set_xlabel('predicted %s (%s)' % (key, units[key]), fontsize=12)
    ax.set_ylabel('target %s (%s)' % (key, units[key]), fontsize=12)

plt.show()

# %% [markdown]
# The model is performing quite well.
